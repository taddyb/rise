# %% [markdown]
# ## PI-3 Running SFINCS using the National Water Model 3.0 inputs
#
# Below is a notebook for running SFINCS using National Water Model inputs over a domain of interest
#
# Author: Tadd Bindas

# %% [markdown]
# ### Step 0: Import dependencies and create national water model data

# %%
# !pip install hydromt hydromt_sfincs zarr networkx
# Out:
# Requirement already satisfied: hydromt in /opt/conda/lib/python3.11/site-packages (0.10.0)
# Requirement already satisfied: hydromt_sfincs in /opt/conda/lib/python3.11/site-packages (1.1.0)
# Requirement already satisfied: zarr in /opt/conda/lib/python3.11/site-packages (2.18.3)
# Requirement already satisfied: networkx in /opt/conda/lib/python3.11/site-packages (3.3)
# Requirement already satisfied: affine in /opt/conda/lib/python3.11/site-packages (from hydromt) (2.4.0)
# Requirement already satisfied: bottleneck in /opt/conda/lib/python3.11/site-packages (from hydromt) (1.4.0)
# Requirement already satisfied: click in /opt/conda/lib/python3.11/site-packages (from hydromt) (8.1.7)
# Requirement already satisfied: dask in /opt/conda/lib/python3.11/site-packages (from hydromt) (2024.8.2)
# Requirement already satisfied: fsspec in /opt/conda/lib/python3.11/site-packages (from hydromt) (2024.9.0)
# Requirement already satisfied: geopandas>=0.10 in /opt/conda/lib/python3.11/site-packages (from hydromt) (1.0.1)
# Requirement already satisfied: importlib_metadata in /opt/conda/lib/python3.11/site-packages (from hydromt) (8.4.0)
# Requirement already satisfied: mercantile in /opt/conda/lib/python3.11/site-packages (from hydromt) (1.2.1)
# Requirement already satisfied: netcdf4 in /opt/conda/lib/python3.11/site-packages (from hydromt) (1.6.5)
# Requirement already satisfied: numba in /opt/conda/lib/python3.11/site-packages (from hydromt) (0.60.0)
# Requirement already satisfied: numpy>=1.23 in /opt/conda/lib/python3.11/site-packages (from hydromt) (1.26.3)
# Requirement already satisfied: packaging in /opt/conda/lib/python3.11/site-packages (from hydromt) (24.1)
# Requirement already satisfied: pandas in /opt/conda/lib/python3.11/site-packages (from hydromt) (2.2.2)
# Requirement already satisfied: pooch in /opt/conda/lib/python3.11/site-packages (from hydromt) (1.8.2)
# Requirement already satisfied: pydantic~=2.4 in /opt/conda/lib/python3.11/site-packages (from hydromt) (2.7.1)
# Requirement already satisfied: pyflwdir>=0.5.4 in /opt/conda/lib/python3.11/site-packages (from hydromt) (0.5.8)
# Requirement already satisfied: pyogrio>=0.6 in /opt/conda/lib/python3.11/site-packages (from hydromt) (0.9.0)
# Requirement already satisfied: pyproj in /opt/conda/lib/python3.11/site-packages (from hydromt) (3.6.1)
# Requirement already satisfied: pystac in /opt/conda/lib/python3.11/site-packages (from hydromt) (1.10.1)
# Requirement already satisfied: pyyaml in /opt/conda/lib/python3.11/site-packages (from hydromt) (6.0.2)
# Requirement already satisfied: rasterio in /opt/conda/lib/python3.11/site-packages (from hydromt) (1.3.11)
# Requirement already satisfied: requests in /opt/conda/lib/python3.11/site-packages (from hydromt) (2.32.3)
# Requirement already satisfied: rioxarray in /opt/conda/lib/python3.11/site-packages (from hydromt) (0.17.0)
# Requirement already satisfied: scipy in /opt/conda/lib/python3.11/site-packages (from hydromt) (1.14.1)
# Requirement already satisfied: shapely>=2.0.0 in /opt/conda/lib/python3.11/site-packages (from hydromt) (2.0.6)
# Requirement already satisfied: tomli in /opt/conda/lib/python3.11/site-packages (from hydromt) (2.0.1)
# Requirement already satisfied: tomli-w in /opt/conda/lib/python3.11/site-packages (from hydromt) (1.0.0)
# Requirement already satisfied: universal_pathlib>=0.2 in /opt/conda/lib/python3.11/site-packages (from hydromt) (0.2.5)
# Requirement already satisfied: xarray==2024.3.0 in /opt/conda/lib/python3.11/site-packages (from hydromt) (2024.3.0)
# Requirement already satisfied: xmltodict in /opt/conda/lib/python3.11/site-packages (from hydromt) (0.13.0)
# Requirement already satisfied: pillow in /opt/conda/lib/python3.11/site-packages (from hydromt_sfincs) (10.4.0)
# Requirement already satisfied: asciitree in /opt/conda/lib/python3.11/site-packages (from zarr) (0.3.3)
# Requirement already satisfied: numcodecs>=0.10.0 in /opt/conda/lib/python3.11/site-packages (from zarr) (0.13.0)
# Requirement already satisfied: fasteners in /opt/conda/lib/python3.11/site-packages (from zarr) (0.19)
# Requirement already satisfied: python-dateutil>=2.8.2 in /opt/conda/lib/python3.11/site-packages (from pandas->hydromt) (2.9.0.post0)
# Requirement already satisfied: pytz>=2020.1 in /opt/conda/lib/python3.11/site-packages (from pandas->hydromt) (2024.1)
# Requirement already satisfied: tzdata>=2022.7 in /opt/conda/lib/python3.11/site-packages (from pandas->hydromt) (2024.1)
# Requirement already satisfied: annotated-types>=0.4.0 in /opt/conda/lib/python3.11/site-packages (from pydantic~=2.4->hydromt) (0.7.0)
# Requirement already satisfied: pydantic-core==2.18.2 in /opt/conda/lib/python3.11/site-packages (from pydantic~=2.4->hydromt) (2.18.2)
# Requirement already satisfied: typing-extensions>=4.6.1 in /opt/conda/lib/python3.11/site-packages (from pydantic~=2.4->hydromt) (4.12.2)
# Requirement already satisfied: llvmlite<0.44,>=0.43.0dev0 in /opt/conda/lib/python3.11/site-packages (from numba->hydromt) (0.43.0)
# Requirement already satisfied: certifi in /opt/conda/lib/python3.11/site-packages (from pyogrio>=0.6->hydromt) (2024.8.30)
# Requirement already satisfied: cloudpickle>=3.0.0 in /opt/conda/lib/python3.11/site-packages (from dask->hydromt) (3.0.0)
# Requirement already satisfied: partd>=1.4.0 in /opt/conda/lib/python3.11/site-packages (from dask->hydromt) (1.4.2)
# Requirement already satisfied: toolz>=0.10.0 in /opt/conda/lib/python3.11/site-packages (from dask->hydromt) (0.12.1)
# Requirement already satisfied: zipp>=0.5 in /opt/conda/lib/python3.11/site-packages (from importlib_metadata->hydromt) (3.20.1)
# Requirement already satisfied: cftime in /opt/conda/lib/python3.11/site-packages (from netcdf4->hydromt) (1.6.4)
# Requirement already satisfied: platformdirs>=2.5.0 in /opt/conda/lib/python3.11/site-packages (from pooch->hydromt) (4.3.2)
# Requirement already satisfied: charset-normalizer<4,>=2 in /opt/conda/lib/python3.11/site-packages (from requests->hydromt) (3.3.2)
# Requirement already satisfied: idna<4,>=2.5 in /opt/conda/lib/python3.11/site-packages (from requests->hydromt) (3.8)
# Requirement already satisfied: urllib3<3,>=1.21.1 in /opt/conda/lib/python3.11/site-packages (from requests->hydromt) (2.2.2)
# Requirement already satisfied: attrs in /opt/conda/lib/python3.11/site-packages (from rasterio->hydromt) (24.2.0)
# Requirement already satisfied: cligj>=0.5 in /opt/conda/lib/python3.11/site-packages (from rasterio->hydromt) (0.7.2)
# Requirement already satisfied: snuggs>=1.4.1 in /opt/conda/lib/python3.11/site-packages (from rasterio->hydromt) (1.4.7)
# Requirement already satisfied: click-plugins in /opt/conda/lib/python3.11/site-packages (from rasterio->hydromt) (1.1.1)
# Requirement already satisfied: setuptools in /opt/conda/lib/python3.11/site-packages (from rasterio->hydromt) (74.1.2)
# Requirement already satisfied: locket in /opt/conda/lib/python3.11/site-packages (from partd>=1.4.0->dask->hydromt) (1.0.0)
# Requirement already satisfied: six>=1.5 in /opt/conda/lib/python3.11/site-packages (from python-dateutil>=2.8.2->pandas->hydromt) (1.16.0)
# Requirement already satisfied: pyparsing>=2.1.6 in /opt/conda/lib/python3.11/site-packages (from snuggs>=1.4.1->rasterio->hydromt) (3.1.4)

# %%
from pathlib import Path

import os
import numpy as np
import pandas as pd
import geopandas as gpd
from shapely.ops import unary_union
import matplotlib.pyplot as plt
import contextily as cx
import networkx as nx
import zarr

import hydromt
from hydromt_sfincs import SfincsModel
from hydromt_sfincs import workflows

# %% [markdown]
# ### Step 1: Define the model:
#
# First, we need to create a SFINCS Model object and some Data Catalogs to point at external data. The SFINCS object saves internal states and a config for mapping to external files

# %%
root = Path("/app/data/NWM/")

yml_str = f"""
meta:
  root: {root.__str__()}
  
10m_lidar:
  path: HUC6_110701_dem.tif
  data_type: RasterDataset
  driver: raster
  driver_kwargs:
    chunks:
      x: 6000
      y: 6000
  meta:
    category: topography
    crs: 5070
  rename:
    10m_lidar: elevtn
"""
data_lib = Path(
    "/app/data/SFINCS/ngwpc_data/10m_huc6_lidar.yml"
)
if data_lib.exists() is False:
    with open(data_lib, mode="w") as f:
        f.write(yml_str)

# %%
data_catalog = hydromt.DataCatalog(data_libs=[data_lib])
sf = SfincsModel(data_libs=[data_lib], root="/app/data/SFINCS/ngwpc_data", mode="w+")

# %% [markdown]
# ### Step 2: Set up the bounding boxes around the catchments of interest
#
# Since we want to determine the flooding downstream of the current RFC station, we have to subset our graph to determine where these catchments exist

# %%
import sys

current_dir = Path.cwd()
src_path = current_dir.parents[0]
sys.path.append(src_path.__str__())

from src.rise.utils import hydrofabric  # noqa: E402

# %%
# Hardcoded HUC8
huc_8 = "11070103"
base_data_path = Path("/app/data/NWM")
output_geojson = base_data_path / f"output_{huc_8}.geojson"
huc8_data = base_data_path / "huc8s_sp.gpkg"
gdf = gpd.read_file(huc8_data)
subset  = gdf[gdf["HUC8"] == huc_8]
subset.to_file(output_geojson, driver='GeoJSON')

# %%
file_path = Path("/app/data/NWM/nextgen_11.gpkg")

flowlines = hydrofabric.get_layer(file_path, layer="flowpaths")
nexus = hydrofabric.get_layer(file_path, layer="nexus")
divides = hydrofabric.get_layer(file_path, layer="divides")
flowpath_attributes = hydrofabric.get_layer(file_path, layer="flowpath_attributes")

G = hydrofabric.get_hydrofabric_vpu_graph(nexus, flowlines)

# %%
# Hardcoded start and end nodes
start_node = "nex-2177032"
end_node = "nex-2175887"
path = nx.shortest_path(G, start_node, end_node)
path
# Out:
# ['nex-2177032',
#  'wb-2177032',
#  'nex-2175879',
#  'wb-2175879',
#  'nex-2175880',
#  'wb-2175880',
#  'nex-2175881',
#  'wb-2175881',
#  'nex-2175882',
#  'wb-2175882',
#  'nex-2175883',
#  'wb-2175883',
#  'nex-2175884',
#  'wb-2175884',
#  'nex-2175885',
#  'wb-2175885',
#  'nex-2175886',
#  'wb-2175886',
#  'nex-2175887']

# %%
mask_flowlines = flowlines["id"].isin(path) | flowlines["toid"].isin(path)
mask_nexus = nexus["id"].isin(path)
mask_divides = divides["id"].isin(path)
# mask_attributes = flowpath_attributes["id"].isin(path)

_subset_nexus = nexus[mask_nexus]
_subset_flowlines = flowlines[mask_flowlines]
_subset_divides = divides[mask_divides]

# %%
fig, ax = plt.subplots(figsize=(10,10))
_subset_divides.plot(ax=ax, edgecolor="k", linewidth=0.5, alpha=0.75,)
_subset_flowlines.plot(ax=ax, color='blue', label='Flowlines')
_subset_nexus.plot(ax=ax, color='red', markersize=30, label='Nexus Points')
try:
    cx.add_basemap(ax, crs=_subset_divides.crs.to_string(), source=cx.providers.OpenStreetMap.Mapnik)
except Exception as e:
    print(f"Couldn't add basemap: {e}")
ax.legend()
plt.title("Downstream Catchments from CFVK1")
plt.tight_layout()
plt.show()

# %%
merged_polygon = unary_union(_subset_divides['geometry'])
merged_gdf = gpd.GeoDataFrame(geometry=[merged_polygon], crs=gdf.crs)
output_divides = "/app/data/NWM/flowlines_divides.geojson"
merged_gdf.to_file(output_divides, driver='GeoJSON')

# %%
sf.setup_grid_from_region(
    region = {'geom': '/app/data/NWM/flowlines_divides.geojson'},
    res= 50,
    rotated=True,
    crs=_subset_divides.crs  # NAD83 / Conus Albers HARDCODED TODO figure out making this cleaner
)
# the input file is automatically updated. Uncomment to displayed below:
print(sf.config)
# Out:
# {'mmax': 199, 'nmax': 499, 'dx': 50, 'dy': 50, 'x0': 32932.0, 'y0': 1533316.0, 'rotation': 5.758, 'latitude': 0.0, 'tref': datetime.datetime(2010, 2, 1, 0, 0), 'tstart': datetime.datetime(2010, 2, 1, 0, 0), 'tstop': datetime.datetime(2010, 2, 2, 0, 0), 'tspinup': 60.0, 'dtout': 3600.0, 'dthisout': 600.0, 'dtrstout': 0.0, 'dtmaxout': 86400, 'trstout': -999.0, 'dtwnd': 1800.0, 'alpha': 0.5, 'theta': 1.0, 'huthresh': 0.01, 'manning': 0.04, 'manning_land': 0.04, 'manning_sea': 0.02, 'rgh_lev_land': 0.0, 'zsini': 0.0, 'qinf': 0.0, 'rhoa': 1.25, 'rhow': 1024.0, 'dtmax': 60.0, 'advection': 1, 'baro': 1, 'pavbnd': 0, 'gapres': 101200.0, 'stopdepth': 100.0, 'crsgeo': 0, 'btfilter': 60.0, 'viscosity': 1, 'inputformat': 'bin', 'outputformat': 'net', 'cdnrb': 3, 'cdwnd': [0.0, 28.0, 50.0], 'cdval': [0.001, 0.0025, 0.0015], 'epsg': 5070}

# %% [markdown]
# ### Step 3: Load in Elevation Data
#
# We're going to be loading in elevation data from FIM-C

# %%
datasets_dep = [{"elevtn": "10m_lidar", "zmin": 0.001}]

dep = sf.setup_dep(datasets_dep=datasets_dep)

_ = sf.plot_basemap(variable="dep", bmap="sat", zoomlevel=12)

# %% [markdown]
# ### Step 4: Mask active cells, boundaries, and coasts
#
# We're going to be masking all active cells as cells above -5 meters. This will properly define coastal vs non-coastal boundaries

# %%
# Choosing how to choose you active cells can be based on multiple criteria, here we only specify a minimum elevation of -5 meters
sf.setup_mask_active(zmin=-5, reset_mask=True)

# Make a plot of the mask file
_ = sf.plot_basemap(variable="msk", plot_bounds=True, bmap="sat", zoomlevel=12)

# %% [markdown]
# ### Step 5: Add output boundaries
#
# We're going to now mask the boundaries of catchments/rivers

# %%
sf.setup_mask_bounds(btype="waterlevel", zmax=-5, reset_bounds=True)

# Here we add outflow cells, only where clicked in shapefile along part of the lateral boundaries
sf.setup_mask_bounds(btype="outflow", include_mask=merged_gdf, reset_bounds=True)

# Make a plot of the mask file
fig, ax = sf.plot_basemap(variable="msk", plot_bounds=True, bmap="sat", zoomlevel=12)
merged_gdf.to_crs(sf.crs).boundary.plot(
    ax=ax, color="k", lw=1, ls="--"
)  # plot the shapefile given by the user as dashed line
# Out:
# <GeoAxes: title={'center': 'SFINCS msk map'}, xlabel='x [m] - NAD83 / Conus Albers', ylabel='y [m]'>

# %% [markdown]
# ### Step 6: Add river inflow data
#
# Using the hydrofabric we can add flowlines to show where rivers are located within the Hydrofabric

# %%
sf.setup_river_inflow(
    rivers=_subset_flowlines, keep_rivers_geom=True
)
print(sf.config)
# Make a plot of model
# note the src points and derived river network
fig, ax = sf.plot_basemap(variable="dep", plot_bounds=False, bmap="sat", zoomlevel=12)
# Out:
# {'mmax': 199, 'nmax': 499, 'dx': 50, 'dy': 50, 'x0': 32932.0, 'y0': 1533316.0, 'rotation': 5.758, 'latitude': 0.0, 'tref': datetime.datetime(2010, 2, 1, 0, 0), 'tstart': datetime.datetime(2010, 2, 1, 0, 0), 'tstop': datetime.datetime(2010, 2, 2, 0, 0), 'tspinup': 60.0, 'dtout': 3600.0, 'dthisout': 600.0, 'dtrstout': 0.0, 'dtmaxout': 86400, 'trstout': -999.0, 'dtwnd': 1800.0, 'alpha': 0.5, 'theta': 1.0, 'huthresh': 0.01, 'manning': 0.04, 'manning_land': 0.04, 'manning_sea': 0.02, 'rgh_lev_land': 0.0, 'zsini': 0.0, 'qinf': 0.0, 'rhoa': 1.25, 'rhow': 1024.0, 'dtmax': 60.0, 'advection': 1, 'baro': 1, 'pavbnd': 0, 'gapres': 101200.0, 'stopdepth': 100.0, 'crsgeo': 0, 'btfilter': 60.0, 'viscosity': 1, 'inputformat': 'bin', 'outputformat': 'net', 'cdnrb': 3, 'cdwnd': [0.0, 28.0, 50.0], 'cdval': [0.001, 0.0025, 0.0015], 'epsg': 5070, 'depfile': 'sfincs.dep', 'mskfile': 'sfincs.msk', 'indexfile': 'sfincs.ind'}

# %%
gdf_riv = sf.geoms["rivers_inflow"].copy()
df_reordered = pd.merge(gdf_riv["id"], flowpath_attributes, on='id', how='left')
gdf_riv["rivwth"] = np.mean(df_reordered["TopWdth"].values) # width [m]

# Assuming depth is 1.5m, TODO come back later
gdf_riv["rivdph"] = 1.5  # depth [m]
gdf_riv["manning"] = df_reordered["n"].tolist()  # manning coefficient [s.m-1/3]
gdf_riv[["geometry", "rivwth", "manning"]]

datasets_riv = [{"centerlines": gdf_riv}]

# %% [markdown]
# ### Step 7: Add spatially varying roughness
#
# Our roughness data needs to be spatially varying, and can use the flowpath attributes in the hydrofabric

# %%
gdf_riv_buf = gdf_riv.assign(geometry=gdf_riv.geometry.buffer(0.2))
# da_manning = sf.grid.raster.rasterize(gdf_riv_buf, "manning", nodata=np.nan)
da_manning = sf.grid.raster.rasterize(gdf_riv, "manning", nodata=np.nan)

# use the river manning raster in combination with vito land to derive the manning roughness file
# NOTE that we can combine in-memory data with data from the data catalog
datasets_rgh = [{"manning": da_manning}]

# uncomment to plot either the raster or the vector data:
da_manning.plot(vmin=0, x='xc', y='yc', cmap='viridis')

# %% [markdown]
# ### Step 8: Make subgrid derived tables:
# Subgrid derived tables are used to better capture the elevation and roughness of your domain, to either improve your results, or to allow you to run on a courser grid resolution (means faster simulation). For more info about subgrid tables, [click here](https://sfincs.readthedocs.io/en/latest/developments.html#recent-advancements-in-accuracy-subgrid-mode).
#
# You as user can specify multiple settings about how the subgrid derived tables should be made.
#
# Every single grid cell of the flux grid of the size inp.dx by inp.dy is defined into subgrid pixels (default nr_subgrid_pixels = 20).
# For every subgrid pixel the topobathy data is loaded, ideally this consists of high-resolution DEM datasets that you specify as user.
#
# In this example with dx=dy=50m, having nr_subgrid_pixels = 20 means we are loading data onto a 2.5 m subpixel grid
# However, the input data of Gebco and Merit_hydro is way coarser, therefore let's set the ratio to 5 for now.

# %%
sf.setup_subgrid(
    datasets_rgh=datasets_rgh,
    datasets_dep=datasets_dep,
    datasets_riv=datasets_riv,
    nr_subgrid_pixels=5,
    write_dep_tif=False,
    write_man_tif=False,
)
_ = sf.plot_basemap(
    variable="subgrid.z_zmin", plot_bounds=False, bmap="sat", zoomlevel=12
)

# %% [markdown]
# ### Step 9: Add an upstream discharge time-series as forcing (NWM retrospective)
#
# We're going to be pulling inputs from the national water model retrospective using TEEHR

# %%
conus_df = pd.read_parquet("/app/data/NWM/conus_net.parquet")
_df = conus_df[conus_df["id"].isin(_subset_flowlines["id"].values)]
_feature_ids = _df[~np.isnan(_df["hf_id"])]
feature_ids = _feature_ids["hf_id"].values.astype(int)
mapping = {}
for _hf_id, _id in zip(_feature_ids["hf_id"], _feature_ids["id"]):
    _mapped_features = mapping.get(_id, None)
    if _mapped_features is None:
        mapping[_id] = [_hf_id]
    else:
        mapping[_id].append(_hf_id)

# %%
# !pip install 'teehr @ git+https://github.com/RTIInternational/teehr@v0.3.28'
# Out:
# Collecting teehr@ git+https://github.com/RTIInternational/teehr@v0.3.28
#   Cloning https://github.com/RTIInternational/teehr (to revision v0.3.28) to /tmp/pip-install-kl2xcks4/teehr_6d0513f83f814df0a568759bbdf70278
#   Running command git clone --filter=blob:none --quiet https://github.com/RTIInternational/teehr /tmp/pip-install-kl2xcks4/teehr_6d0513f83f814df0a568759bbdf70278
#   Running command git checkout -q 3f7f714c6f722428ee059610c3938d4abb246f86
#   Resolved https://github.com/RTIInternational/teehr to commit 3f7f714c6f722428ee059610c3938d4abb246f86
#   Installing build dependencies ... done
#   Getting requirements to build wheel ... done
#   Preparing metadata (pyproject.toml) ... done
# Requirement already satisfied: dask>=2023.8.1 in /opt/conda/lib/python3.11/site-packages (from teehr@ git+https://github.com/RTIInternational/teehr@v0.3.28) (2024.8.2)
# Collecting duckdb<0.10.0,>=0.9.2 (from teehr@ git+https://github.com/RTIInternational/teehr@v0.3.28)
#   Downloading duckdb-0.9.2-cp311-cp311-manylinux_2_17_x86_64.manylinux2014_x86_64.whl.metadata (760 bytes)
# Collecting fastapi<0.104.0,>=0.103.0 (from teehr@ git+https://github.com/RTIInternational/teehr@v0.3.28)
#   Downloading fastapi-0.103.2-py3-none-any.whl.metadata (24 kB)
# Requirement already satisfied: fsspec>=2023.10.0 in /opt/conda/lib/python3.11/site-packages (from teehr@ git+https://github.com/RTIInternational/teehr@v0.3.28) (2024.9.0)
# Collecting gcsfs>=2023.10.0 (from teehr@ git+https://github.com/RTIInternational/teehr@v0.3.28)
#   Downloading gcsfs-2024.9.0.post1-py2.py3-none-any.whl.metadata (1.6 kB)
# Collecting geopandas<0.15.0,>=0.14.0 (from teehr@ git+https://github.com/RTIInternational/teehr@v0.3.28)
#   Downloading geopandas-0.14.4-py3-none-any.whl.metadata (1.5 kB)
# Collecting h5py<4.0.0,>=3.10.0 (from teehr@ git+https://github.com/RTIInternational/teehr@v0.3.28)
#   Downloading h5py-3.11.0-cp311-cp311-manylinux_2_17_x86_64.manylinux2014_x86_64.whl.metadata (2.5 kB)
# Collecting httpx<0.26.0,>=0.25.1 (from teehr@ git+https://github.com/RTIInternational/teehr@v0.3.28)
#   Downloading httpx-0.25.2-py3-none-any.whl.metadata (6.9 kB)
# Collecting hydrotools-metrics<2.0.0,>=1.3.3 (from teehr@ git+https://github.com/RTIInternational/teehr@v0.3.28)
#   Downloading hydrotools.metrics-1.3.3-py3-none-any.whl.metadata (4.4 kB)
# Collecting hydrotools-nwis-client<4.0.0,>=3.3.1 (from teehr@ git+https://github.com/RTIInternational/teehr@v0.3.28)
#   Downloading hydrotools.nwis_client-3.3.1-py3-none-any.whl.metadata (7.3 kB)
# Collecting kerchunk<0.3.0,>=0.2.2 (from teehr@ git+https://github.com/RTIInternational/teehr@v0.3.28)
#   Downloading kerchunk-0.2.6-py3-none-any.whl.metadata (4.3 kB)
# Requirement already satisfied: pandas<3.0.0,>=2.2.0 in /opt/conda/lib/python3.11/site-packages (from teehr@ git+https://github.com/RTIInternational/teehr@v0.3.28) (2.2.2)
# Collecting pyarrow<15.0.0,>=14.0.1 (from teehr@ git+https://github.com/RTIInternational/teehr@v0.3.28)
#   Downloading pyarrow-14.0.2-cp311-cp311-manylinux_2_28_x86_64.whl.metadata (3.0 kB)
# Requirement already satisfied: pydantic<3.0.0,>=2.4.2 in /opt/conda/lib/python3.11/site-packages (from teehr@ git+https://github.com/RTIInternational/teehr@v0.3.28) (2.7.1)
# Collecting pydata-sphinx-theme<0.16.0,>=0.15.4 (from teehr@ git+https://github.com/RTIInternational/teehr@v0.3.28)
#   Downloading pydata_sphinx_theme-0.15.4-py3-none-any.whl.metadata (7.5 kB)
# Requirement already satisfied: rasterio<2.0.0,>=1.3.9 in /opt/conda/lib/python3.11/site-packages (from teehr@ git+https://github.com/RTIInternational/teehr@v0.3.28) (1.3.11)
# Collecting rioxarray<0.16.0,>=0.15.0 (from teehr@ git+https://github.com/RTIInternational/teehr@v0.3.28)
#   Downloading rioxarray-0.15.7-py3-none-any.whl.metadata (5.4 kB)
# Collecting s3fs>=2023.10.0 (from teehr@ git+https://github.com/RTIInternational/teehr@v0.3.28)
#   Downloading s3fs-2024.9.0-py3-none-any.whl.metadata (1.6 kB)
# Collecting ujson<6.0.0,>=5.8.0 (from teehr@ git+https://github.com/RTIInternational/teehr@v0.3.28)
#   Downloading ujson-5.10.0-cp311-cp311-manylinux_2_17_x86_64.manylinux2014_x86_64.whl.metadata (9.3 kB)
# Collecting uvicorn<0.25.0,>=0.24.0.post1 (from uvicorn[standard]<0.25.0,>=0.24.0.post1->teehr@ git+https://github.com/RTIInternational/teehr@v0.3.28)
#   Downloading uvicorn-0.24.0.post1-py3-none-any.whl.metadata (6.4 kB)
# Requirement already satisfied: zarr<3.0.0,>=2.16.1 in /opt/conda/lib/python3.11/site-packages (from teehr@ git+https://github.com/RTIInternational/teehr@v0.3.28) (2.18.3)
# Requirement already satisfied: click>=8.1 in /opt/conda/lib/python3.11/site-packages (from dask>=2023.8.1->teehr@ git+https://github.com/RTIInternational/teehr@v0.3.28) (8.1.7)
# Requirement already satisfied: cloudpickle>=3.0.0 in /opt/conda/lib/python3.11/site-packages (from dask>=2023.8.1->teehr@ git+https://github.com/RTIInternational/teehr@v0.3.28) (3.0.0)
# Requirement already satisfied: packaging>=20.0 in /opt/conda/lib/python3.11/site-packages (from dask>=2023.8.1->teehr@ git+https://github.com/RTIInternational/teehr@v0.3.28) (24.1)
# Requirement already satisfied: partd>=1.4.0 in /opt/conda/lib/python3.11/site-packages (from dask>=2023.8.1->teehr@ git+https://github.com/RTIInternational/teehr@v0.3.28) (1.4.2)
# Requirement already satisfied: pyyaml>=5.3.1 in /opt/conda/lib/python3.11/site-packages (from dask>=2023.8.1->teehr@ git+https://github.com/RTIInternational/teehr@v0.3.28) (6.0.2)
# Requirement already satisfied: toolz>=0.10.0 in /opt/conda/lib/python3.11/site-packages (from dask>=2023.8.1->teehr@ git+https://github.com/RTIInternational/teehr@v0.3.28) (0.12.1)
# Requirement already satisfied: importlib-metadata>=4.13.0 in /opt/conda/lib/python3.11/site-packages (from dask>=2023.8.1->teehr@ git+https://github.com/RTIInternational/teehr@v0.3.28) (8.4.0)
# Collecting anyio<4.0.0,>=3.7.1 (from fastapi<0.104.0,>=0.103.0->teehr@ git+https://github.com/RTIInternational/teehr@v0.3.28)
#   Downloading anyio-3.7.1-py3-none-any.whl.metadata (4.7 kB)
# Collecting starlette<0.28.0,>=0.27.0 (from fastapi<0.104.0,>=0.103.0->teehr@ git+https://github.com/RTIInternational/teehr@v0.3.28)
#   Downloading starlette-0.27.0-py3-none-any.whl.metadata (5.8 kB)
# Requirement already satisfied: typing-extensions>=4.5.0 in /opt/conda/lib/python3.11/site-packages (from fastapi<0.104.0,>=0.103.0->teehr@ git+https://github.com/RTIInternational/teehr@v0.3.28) (4.12.2)
# Collecting aiohttp!=4.0.0a0,!=4.0.0a1 (from gcsfs>=2023.10.0->teehr@ git+https://github.com/RTIInternational/teehr@v0.3.28)
#   Downloading aiohttp-3.10.5-cp311-cp311-manylinux_2_17_x86_64.manylinux2014_x86_64.whl.metadata (7.5 kB)
# Requirement already satisfied: decorator>4.1.2 in /opt/conda/lib/python3.11/site-packages (from gcsfs>=2023.10.0->teehr@ git+https://github.com/RTIInternational/teehr@v0.3.28) (5.1.1)
# Collecting google-auth>=1.2 (from gcsfs>=2023.10.0->teehr@ git+https://github.com/RTIInternational/teehr@v0.3.28)
#   Downloading google_auth-2.35.0-py2.py3-none-any.whl.metadata (4.7 kB)
# Collecting google-auth-oauthlib (from gcsfs>=2023.10.0->teehr@ git+https://github.com/RTIInternational/teehr@v0.3.28)
#   Downloading google_auth_oauthlib-1.2.1-py2.py3-none-any.whl.metadata (2.7 kB)
# Collecting google-cloud-storage (from gcsfs>=2023.10.0->teehr@ git+https://github.com/RTIInternational/teehr@v0.3.28)
#   Downloading google_cloud_storage-2.18.2-py2.py3-none-any.whl.metadata (9.1 kB)
# Requirement already satisfied: requests in /opt/conda/lib/python3.11/site-packages (from gcsfs>=2023.10.0->teehr@ git+https://github.com/RTIInternational/teehr@v0.3.28) (2.32.3)
# Collecting fiona>=1.8.21 (from geopandas<0.15.0,>=0.14.0->teehr@ git+https://github.com/RTIInternational/teehr@v0.3.28)
#   Downloading fiona-1.10.1-cp311-cp311-manylinux_2_17_x86_64.manylinux2014_x86_64.whl.metadata (56 kB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 56.6/56.6 kB 1.9 MB/s eta 0:00:00
# Requirement already satisfied: numpy>=1.22 in /opt/conda/lib/python3.11/site-packages (from geopandas<0.15.0,>=0.14.0->teehr@ git+https://github.com/RTIInternational/teehr@v0.3.28) (1.26.3)
# Requirement already satisfied: pyproj>=3.3.0 in /opt/conda/lib/python3.11/site-packages (from geopandas<0.15.0,>=0.14.0->teehr@ git+https://github.com/RTIInternational/teehr@v0.3.28) (3.6.1)
# Requirement already satisfied: shapely>=1.8.0 in /opt/conda/lib/python3.11/site-packages (from geopandas<0.15.0,>=0.14.0->teehr@ git+https://github.com/RTIInternational/teehr@v0.3.28) (2.0.6)
# Requirement already satisfied: certifi in /opt/conda/lib/python3.11/site-packages (from httpx<0.26.0,>=0.25.1->teehr@ git+https://github.com/RTIInternational/teehr@v0.3.28) (2024.8.30)
# Requirement already satisfied: httpcore==1.* in /opt/conda/lib/python3.11/site-packages (from httpx<0.26.0,>=0.25.1->teehr@ git+https://github.com/RTIInternational/teehr@v0.3.28) (1.0.5)
# Requirement already satisfied: idna in /opt/conda/lib/python3.11/site-packages (from httpx<0.26.0,>=0.25.1->teehr@ git+https://github.com/RTIInternational/teehr@v0.3.28) (3.8)
# Requirement already satisfied: sniffio in /opt/conda/lib/python3.11/site-packages (from httpx<0.26.0,>=0.25.1->teehr@ git+https://github.com/RTIInternational/teehr@v0.3.28) (1.3.1)
# Requirement already satisfied: h11<0.15,>=0.13 in /opt/conda/lib/python3.11/site-packages (from httpcore==1.*->httpx<0.26.0,>=0.25.1->teehr@ git+https://github.com/RTIInternational/teehr@v0.3.28) (0.14.0)
# Collecting hydrotools.-restclient>=3.0.4 (from hydrotools-nwis-client<4.0.0,>=3.3.1->teehr@ git+https://github.com/RTIInternational/teehr@v0.3.28)
#   Downloading hydrotools_restclient-3.1.0-py3-none-any.whl.metadata (4.9 kB)
# Requirement already satisfied: numcodecs in /opt/conda/lib/python3.11/site-packages (from kerchunk<0.3.0,>=0.2.2->teehr@ git+https://github.com/RTIInternational/teehr@v0.3.28) (0.13.0)
# Requirement already satisfied: python-dateutil>=2.8.2 in /opt/conda/lib/python3.11/site-packages (from pandas<3.0.0,>=2.2.0->teehr@ git+https://github.com/RTIInternational/teehr@v0.3.28) (2.9.0.post0)
# Requirement already satisfied: pytz>=2020.1 in /opt/conda/lib/python3.11/site-packages (from pandas<3.0.0,>=2.2.0->teehr@ git+https://github.com/RTIInternational/teehr@v0.3.28) (2024.1)
# Requirement already satisfied: tzdata>=2022.7 in /opt/conda/lib/python3.11/site-packages (from pandas<3.0.0,>=2.2.0->teehr@ git+https://github.com/RTIInternational/teehr@v0.3.28) (2024.1)
# Requirement already satisfied: annotated-types>=0.4.0 in /opt/conda/lib/python3.11/site-packages (from pydantic<3.0.0,>=2.4.2->teehr@ git+https://github.com/RTIInternational/teehr@v0.3.28) (0.7.0)
# Requirement already satisfied: pydantic-core==2.18.2 in /opt/conda/lib/python3.11/site-packages (from pydantic<3.0.0,>=2.4.2->teehr@ git+https://github.com/RTIInternational/teehr@v0.3.28) (2.18.2)
# Collecting sphinx>=5 (from pydata-sphinx-theme<0.16.0,>=0.15.4->teehr@ git+https://github.com/RTIInternational/teehr@v0.3.28)
#   Downloading sphinx-8.0.2-py3-none-any.whl.metadata (6.2 kB)
# Requirement already satisfied: beautifulsoup4 in /opt/conda/lib/python3.11/site-packages (from pydata-sphinx-theme<0.16.0,>=0.15.4->teehr@ git+https://github.com/RTIInternational/teehr@v0.3.28) (4.12.2)
# Collecting docutils!=0.17.0 (from pydata-sphinx-theme<0.16.0,>=0.15.4->teehr@ git+https://github.com/RTIInternational/teehr@v0.3.28)
#   Downloading docutils-0.21.2-py3-none-any.whl.metadata (2.8 kB)
# Requirement already satisfied: Babel in /opt/conda/lib/python3.11/site-packages (from pydata-sphinx-theme<0.16.0,>=0.15.4->teehr@ git+https://github.com/RTIInternational/teehr@v0.3.28) (2.13.0)
# Requirement already satisfied: pygments>=2.7 in /opt/conda/lib/python3.11/site-packages (from pydata-sphinx-theme<0.16.0,>=0.15.4->teehr@ git+https://github.com/RTIInternational/teehr@v0.3.28) (2.16.1)
# Collecting accessible-pygments (from pydata-sphinx-theme<0.16.0,>=0.15.4->teehr@ git+https://github.com/RTIInternational/teehr@v0.3.28)
#   Downloading accessible_pygments-0.0.5-py3-none-any.whl.metadata (10 kB)
# Requirement already satisfied: affine in /opt/conda/lib/python3.11/site-packages (from rasterio<2.0.0,>=1.3.9->teehr@ git+https://github.com/RTIInternational/teehr@v0.3.28) (2.4.0)
# Requirement already satisfied: attrs in /opt/conda/lib/python3.11/site-packages (from rasterio<2.0.0,>=1.3.9->teehr@ git+https://github.com/RTIInternational/teehr@v0.3.28) (24.2.0)
# Requirement already satisfied: cligj>=0.5 in /opt/conda/lib/python3.11/site-packages (from rasterio<2.0.0,>=1.3.9->teehr@ git+https://github.com/RTIInternational/teehr@v0.3.28) (0.7.2)
# Requirement already satisfied: snuggs>=1.4.1 in /opt/conda/lib/python3.11/site-packages (from rasterio<2.0.0,>=1.3.9->teehr@ git+https://github.com/RTIInternational/teehr@v0.3.28) (1.4.7)
# Requirement already satisfied: click-plugins in /opt/conda/lib/python3.11/site-packages (from rasterio<2.0.0,>=1.3.9->teehr@ git+https://github.com/RTIInternational/teehr@v0.3.28) (1.1.1)
# Requirement already satisfied: setuptools in /opt/conda/lib/python3.11/site-packages (from rasterio<2.0.0,>=1.3.9->teehr@ git+https://github.com/RTIInternational/teehr@v0.3.28) (74.1.2)
# Requirement already satisfied: xarray>=2022.3.0 in /opt/conda/lib/python3.11/site-packages (from rioxarray<0.16.0,>=0.15.0->teehr@ git+https://github.com/RTIInternational/teehr@v0.3.28) (2024.3.0)
# Collecting aiobotocore<3.0.0,>=2.5.4 (from s3fs>=2023.10.0->teehr@ git+https://github.com/RTIInternational/teehr@v0.3.28)
#   Downloading aiobotocore-2.15.1-py3-none-any.whl.metadata (23 kB)
# Collecting httptools>=0.5.0 (from uvicorn[standard]<0.25.0,>=0.24.0.post1->teehr@ git+https://github.com/RTIInternational/teehr@v0.3.28)
#   Downloading httptools-0.6.1-cp311-cp311-manylinux_2_5_x86_64.manylinux1_x86_64.manylinux_2_17_x86_64.manylinux2014_x86_64.whl.metadata (3.6 kB)
# Requirement already satisfied: python-dotenv>=0.13 in /opt/conda/lib/python3.11/site-packages (from uvicorn[standard]<0.25.0,>=0.24.0.post1->teehr@ git+https://github.com/RTIInternational/teehr@v0.3.28) (1.0.1)
# Collecting uvloop!=0.15.0,!=0.15.1,>=0.14.0 (from uvicorn[standard]<0.25.0,>=0.24.0.post1->teehr@ git+https://github.com/RTIInternational/teehr@v0.3.28)
#   Downloading uvloop-0.20.0-cp311-cp311-manylinux_2_17_x86_64.manylinux2014_x86_64.whl.metadata (4.9 kB)
# Collecting watchfiles>=0.13 (from uvicorn[standard]<0.25.0,>=0.24.0.post1->teehr@ git+https://github.com/RTIInternational/teehr@v0.3.28)
#   Downloading watchfiles-0.24.0-cp311-cp311-manylinux_2_17_x86_64.manylinux2014_x86_64.whl.metadata (4.9 kB)
# Collecting websockets>=10.4 (from uvicorn[standard]<0.25.0,>=0.24.0.post1->teehr@ git+https://github.com/RTIInternational/teehr@v0.3.28)
#   Downloading websockets-13.0.1-cp311-cp311-manylinux_2_5_x86_64.manylinux1_x86_64.manylinux_2_17_x86_64.manylinux2014_x86_64.whl.metadata (6.7 kB)
# Requirement already satisfied: asciitree in /opt/conda/lib/python3.11/site-packages (from zarr<3.0.0,>=2.16.1->teehr@ git+https://github.com/RTIInternational/teehr@v0.3.28) (0.3.3)
# Requirement already satisfied: fasteners in /opt/conda/lib/python3.11/site-packages (from zarr<3.0.0,>=2.16.1->teehr@ git+https://github.com/RTIInternational/teehr@v0.3.28) (0.19)
# Collecting botocore<1.35.24,>=1.35.16 (from aiobotocore<3.0.0,>=2.5.4->s3fs>=2023.10.0->teehr@ git+https://github.com/RTIInternational/teehr@v0.3.28)
#   Downloading botocore-1.35.23-py3-none-any.whl.metadata (5.7 kB)
# Collecting wrapt<2.0.0,>=1.10.10 (from aiobotocore<3.0.0,>=2.5.4->s3fs>=2023.10.0->teehr@ git+https://github.com/RTIInternational/teehr@v0.3.28)
#   Downloading wrapt-1.16.0-cp311-cp311-manylinux_2_5_x86_64.manylinux1_x86_64.manylinux_2_17_x86_64.manylinux2014_x86_64.whl.metadata (6.6 kB)
# Collecting aioitertools<1.0.0,>=0.5.1 (from aiobotocore<3.0.0,>=2.5.4->s3fs>=2023.10.0->teehr@ git+https://github.com/RTIInternational/teehr@v0.3.28)
#   Downloading aioitertools-0.12.0-py3-none-any.whl.metadata (3.8 kB)
# Collecting aiohappyeyeballs>=2.3.0 (from aiohttp!=4.0.0a0,!=4.0.0a1->gcsfs>=2023.10.0->teehr@ git+https://github.com/RTIInternational/teehr@v0.3.28)
#   Downloading aiohappyeyeballs-2.4.0-py3-none-any.whl.metadata (5.9 kB)
# Collecting aiosignal>=1.1.2 (from aiohttp!=4.0.0a0,!=4.0.0a1->gcsfs>=2023.10.0->teehr@ git+https://github.com/RTIInternational/teehr@v0.3.28)
#   Downloading aiosignal-1.3.1-py3-none-any.whl.metadata (4.0 kB)
# Collecting frozenlist>=1.1.1 (from aiohttp!=4.0.0a0,!=4.0.0a1->gcsfs>=2023.10.0->teehr@ git+https://github.com/RTIInternational/teehr@v0.3.28)
#   Downloading frozenlist-1.4.1-cp311-cp311-manylinux_2_5_x86_64.manylinux1_x86_64.manylinux_2_17_x86_64.manylinux2014_x86_64.whl.metadata (12 kB)
# Requirement already satisfied: multidict<7.0,>=4.5 in /opt/conda/lib/python3.11/site-packages (from aiohttp!=4.0.0a0,!=4.0.0a1->gcsfs>=2023.10.0->teehr@ git+https://github.com/RTIInternational/teehr@v0.3.28) (6.0.5)
# Requirement already satisfied: yarl<2.0,>=1.0 in /opt/conda/lib/python3.11/site-packages (from aiohttp!=4.0.0a0,!=4.0.0a1->gcsfs>=2023.10.0->teehr@ git+https://github.com/RTIInternational/teehr@v0.3.28) (1.9.11)
# Collecting cachetools<6.0,>=2.0.0 (from google-auth>=1.2->gcsfs>=2023.10.0->teehr@ git+https://github.com/RTIInternational/teehr@v0.3.28)
#   Downloading cachetools-5.5.0-py3-none-any.whl.metadata (5.3 kB)
# Collecting pyasn1-modules>=0.2.1 (from google-auth>=1.2->gcsfs>=2023.10.0->teehr@ git+https://github.com/RTIInternational/teehr@v0.3.28)
#   Downloading pyasn1_modules-0.4.1-py3-none-any.whl.metadata (3.5 kB)
# Collecting rsa<5,>=3.1.4 (from google-auth>=1.2->gcsfs>=2023.10.0->teehr@ git+https://github.com/RTIInternational/teehr@v0.3.28)
#   Downloading rsa-4.9-py3-none-any.whl.metadata (4.2 kB)
# Collecting aiohttp-client-cache>=0.9.0 (from aiohttp-client-cache[sqlite]>=0.9.0->hydrotools.-restclient>=3.0.4->hydrotools-nwis-client<4.0.0,>=3.3.1->teehr@ git+https://github.com/RTIInternational/teehr@v0.3.28)
#   Downloading aiohttp_client_cache-0.11.1-py3-none-any.whl.metadata (7.5 kB)
# Collecting python-forge (from hydrotools.-restclient>=3.0.4->hydrotools-nwis-client<4.0.0,>=3.3.1->teehr@ git+https://github.com/RTIInternational/teehr@v0.3.28)
#   Downloading python_forge-18.6.0-py35-none-any.whl.metadata (6.6 kB)
# Collecting aiosqlite (from hydrotools.-restclient>=3.0.4->hydrotools-nwis-client<4.0.0,>=3.3.1->teehr@ git+https://github.com/RTIInternational/teehr@v0.3.28)
#   Downloading aiosqlite-0.20.0-py3-none-any.whl.metadata (4.3 kB)
# Requirement already satisfied: zipp>=0.5 in /opt/conda/lib/python3.11/site-packages (from importlib-metadata>=4.13.0->dask>=2023.8.1->teehr@ git+https://github.com/RTIInternational/teehr@v0.3.28) (3.20.1)
# Requirement already satisfied: locket in /opt/conda/lib/python3.11/site-packages (from partd>=1.4.0->dask>=2023.8.1->teehr@ git+https://github.com/RTIInternational/teehr@v0.3.28) (1.0.0)
# Requirement already satisfied: six>=1.5 in /opt/conda/lib/python3.11/site-packages (from python-dateutil>=2.8.2->pandas<3.0.0,>=2.2.0->teehr@ git+https://github.com/RTIInternational/teehr@v0.3.28) (1.16.0)
# Requirement already satisfied: pyparsing>=2.1.6 in /opt/conda/lib/python3.11/site-packages (from snuggs>=1.4.1->rasterio<2.0.0,>=1.3.9->teehr@ git+https://github.com/RTIInternational/teehr@v0.3.28) (3.1.4)
# Collecting sphinxcontrib-applehelp (from sphinx>=5->pydata-sphinx-theme<0.16.0,>=0.15.4->teehr@ git+https://github.com/RTIInternational/teehr@v0.3.28)
#   Downloading sphinxcontrib_applehelp-2.0.0-py3-none-any.whl.metadata (2.3 kB)
# Collecting sphinxcontrib-devhelp (from sphinx>=5->pydata-sphinx-theme<0.16.0,>=0.15.4->teehr@ git+https://github.com/RTIInternational/teehr@v0.3.28)
#   Downloading sphinxcontrib_devhelp-2.0.0-py3-none-any.whl.metadata (2.3 kB)
# Collecting sphinxcontrib-jsmath (from sphinx>=5->pydata-sphinx-theme<0.16.0,>=0.15.4->teehr@ git+https://github.com/RTIInternational/teehr@v0.3.28)
#   Downloading sphinxcontrib_jsmath-1.0.1-py2.py3-none-any.whl.metadata (1.4 kB)
# Collecting sphinxcontrib-htmlhelp>=2.0.0 (from sphinx>=5->pydata-sphinx-theme<0.16.0,>=0.15.4->teehr@ git+https://github.com/RTIInternational/teehr@v0.3.28)
#   Downloading sphinxcontrib_htmlhelp-2.1.0-py3-none-any.whl.metadata (2.3 kB)
# Collecting sphinxcontrib-serializinghtml>=1.1.9 (from sphinx>=5->pydata-sphinx-theme<0.16.0,>=0.15.4->teehr@ git+https://github.com/RTIInternational/teehr@v0.3.28)
#   Downloading sphinxcontrib_serializinghtml-2.0.0-py3-none-any.whl.metadata (2.4 kB)
# Collecting sphinxcontrib-qthelp (from sphinx>=5->pydata-sphinx-theme<0.16.0,>=0.15.4->teehr@ git+https://github.com/RTIInternational/teehr@v0.3.28)
#   Downloading sphinxcontrib_qthelp-2.0.0-py3-none-any.whl.metadata (2.3 kB)
# Requirement already satisfied: Jinja2>=3.1 in /opt/conda/lib/python3.11/site-packages (from sphinx>=5->pydata-sphinx-theme<0.16.0,>=0.15.4->teehr@ git+https://github.com/RTIInternational/teehr@v0.3.28) (3.1.2)
# Collecting pygments>=2.7 (from pydata-sphinx-theme<0.16.0,>=0.15.4->teehr@ git+https://github.com/RTIInternational/teehr@v0.3.28)
#   Downloading pygments-2.18.0-py3-none-any.whl.metadata (2.5 kB)
# Collecting snowballstemmer>=2.2 (from sphinx>=5->pydata-sphinx-theme<0.16.0,>=0.15.4->teehr@ git+https://github.com/RTIInternational/teehr@v0.3.28)
#   Downloading snowballstemmer-2.2.0-py2.py3-none-any.whl.metadata (6.5 kB)
# Collecting alabaster>=0.7.14 (from sphinx>=5->pydata-sphinx-theme<0.16.0,>=0.15.4->teehr@ git+https://github.com/RTIInternational/teehr@v0.3.28)
#   Downloading alabaster-1.0.0-py3-none-any.whl.metadata (2.8 kB)
# Collecting imagesize>=1.3 (from sphinx>=5->pydata-sphinx-theme<0.16.0,>=0.15.4->teehr@ git+https://github.com/RTIInternational/teehr@v0.3.28)
#   Downloading imagesize-1.4.1-py2.py3-none-any.whl.metadata (1.5 kB)
# Requirement already satisfied: charset-normalizer<4,>=2 in /opt/conda/lib/python3.11/site-packages (from requests->gcsfs>=2023.10.0->teehr@ git+https://github.com/RTIInternational/teehr@v0.3.28) (3.3.2)
# Requirement already satisfied: urllib3<3,>=1.21.1 in /opt/conda/lib/python3.11/site-packages (from requests->gcsfs>=2023.10.0->teehr@ git+https://github.com/RTIInternational/teehr@v0.3.28) (2.2.2)
# Requirement already satisfied: soupsieve>1.2 in /opt/conda/lib/python3.11/site-packages (from beautifulsoup4->pydata-sphinx-theme<0.16.0,>=0.15.4->teehr@ git+https://github.com/RTIInternational/teehr@v0.3.28) (2.5)
# Collecting requests-oauthlib>=0.7.0 (from google-auth-oauthlib->gcsfs>=2023.10.0->teehr@ git+https://github.com/RTIInternational/teehr@v0.3.28)
#   Downloading requests_oauthlib-2.0.0-py2.py3-none-any.whl.metadata (11 kB)
# Collecting google-api-core<3.0.0dev,>=2.15.0 (from google-cloud-storage->gcsfs>=2023.10.0->teehr@ git+https://github.com/RTIInternational/teehr@v0.3.28)
#   Downloading google_api_core-2.20.0-py3-none-any.whl.metadata (2.7 kB)
# Collecting google-cloud-core<3.0dev,>=2.3.0 (from google-cloud-storage->gcsfs>=2023.10.0->teehr@ git+https://github.com/RTIInternational/teehr@v0.3.28)
#   Downloading google_cloud_core-2.4.1-py2.py3-none-any.whl.metadata (2.7 kB)
# Collecting google-resumable-media>=2.7.2 (from google-cloud-storage->gcsfs>=2023.10.0->teehr@ git+https://github.com/RTIInternational/teehr@v0.3.28)
#   Downloading google_resumable_media-2.7.2-py2.py3-none-any.whl.metadata (2.2 kB)
# Collecting google-crc32c<2.0dev,>=1.0 (from google-cloud-storage->gcsfs>=2023.10.0->teehr@ git+https://github.com/RTIInternational/teehr@v0.3.28)
#   Downloading google_crc32c-1.6.0-cp311-cp311-manylinux_2_17_x86_64.manylinux2014_x86_64.whl.metadata (2.3 kB)
# Collecting itsdangerous>=2.0 (from aiohttp-client-cache>=0.9.0->aiohttp-client-cache[sqlite]>=0.9.0->hydrotools.-restclient>=3.0.4->hydrotools-nwis-client<4.0.0,>=3.3.1->teehr@ git+https://github.com/RTIInternational/teehr@v0.3.28)
#   Downloading itsdangerous-2.2.0-py3-none-any.whl.metadata (1.9 kB)
# Collecting url-normalize<2.0,>=1.4 (from aiohttp-client-cache>=0.9.0->aiohttp-client-cache[sqlite]>=0.9.0->hydrotools.-restclient>=3.0.4->hydrotools-nwis-client<4.0.0,>=3.3.1->teehr@ git+https://github.com/RTIInternational/teehr@v0.3.28)
#   Downloading url_normalize-1.4.3-py2.py3-none-any.whl.metadata (3.1 kB)
# Collecting jmespath<2.0.0,>=0.7.1 (from botocore<1.35.24,>=1.35.16->aiobotocore<3.0.0,>=2.5.4->s3fs>=2023.10.0->teehr@ git+https://github.com/RTIInternational/teehr@v0.3.28)
#   Downloading jmespath-1.0.1-py3-none-any.whl.metadata (7.6 kB)
# Collecting googleapis-common-protos<2.0.dev0,>=1.56.2 (from google-api-core<3.0.0dev,>=2.15.0->google-cloud-storage->gcsfs>=2023.10.0->teehr@ git+https://github.com/RTIInternational/teehr@v0.3.28)
#   Downloading googleapis_common_protos-1.65.0-py2.py3-none-any.whl.metadata (1.5 kB)
# Collecting protobuf!=3.20.0,!=3.20.1,!=4.21.0,!=4.21.1,!=4.21.2,!=4.21.3,!=4.21.4,!=4.21.5,<6.0.0.dev0,>=3.19.5 (from google-api-core<3.0.0dev,>=2.15.0->google-cloud-storage->gcsfs>=2023.10.0->teehr@ git+https://github.com/RTIInternational/teehr@v0.3.28)
#   Downloading protobuf-5.28.2-cp38-abi3-manylinux2014_x86_64.whl.metadata (592 bytes)
# Collecting proto-plus<2.0.0dev,>=1.22.3 (from google-api-core<3.0.0dev,>=2.15.0->google-cloud-storage->gcsfs>=2023.10.0->teehr@ git+https://github.com/RTIInternational/teehr@v0.3.28)
#   Downloading proto_plus-1.24.0-py3-none-any.whl.metadata (2.2 kB)
# Requirement already satisfied: MarkupSafe>=2.0 in /opt/conda/lib/python3.11/site-packages (from Jinja2>=3.1->sphinx>=5->pydata-sphinx-theme<0.16.0,>=0.15.4->teehr@ git+https://github.com/RTIInternational/teehr@v0.3.28) (2.1.3)
# Collecting pyasn1<0.7.0,>=0.4.6 (from pyasn1-modules>=0.2.1->google-auth>=1.2->gcsfs>=2023.10.0->teehr@ git+https://github.com/RTIInternational/teehr@v0.3.28)
#   Downloading pyasn1-0.6.1-py3-none-any.whl.metadata (8.4 kB)
# Requirement already satisfied: oauthlib>=3.0.0 in /opt/conda/lib/python3.11/site-packages (from requests-oauthlib>=0.7.0->google-auth-oauthlib->gcsfs>=2023.10.0->teehr@ git+https://github.com/RTIInternational/teehr@v0.3.28) (3.2.2)
# Downloading duckdb-0.9.2-cp311-cp311-manylinux_2_17_x86_64.manylinux2014_x86_64.whl (16.5 MB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 16.5/16.5 MB 39.6 MB/s eta 0:00:00:00:010:01
# Downloading fastapi-0.103.2-py3-none-any.whl (66 kB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 66.3/66.3 kB 12.4 MB/s eta 0:00:00
# Downloading gcsfs-2024.9.0.post1-py2.py3-none-any.whl (34 kB)
# Downloading geopandas-0.14.4-py3-none-any.whl (1.1 MB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 1.1/1.1 MB 87.0 MB/s eta 0:00:00
# Downloading h5py-3.11.0-cp311-cp311-manylinux_2_17_x86_64.manylinux2014_x86_64.whl (5.4 MB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 5.4/5.4 MB 24.2 MB/s eta 0:00:00:00:01
# Downloading httpx-0.25.2-py3-none-any.whl (74 kB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 75.0/75.0 kB 13.2 MB/s eta 0:00:00
# Downloading hydrotools.metrics-1.3.3-py3-none-any.whl (10 kB)
# Downloading hydrotools.nwis_client-3.3.1-py3-none-any.whl (15 kB)
# Downloading kerchunk-0.2.6-py3-none-any.whl (134 kB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 134.6/134.6 kB 28.4 MB/s eta 0:00:00
# Downloading pyarrow-14.0.2-cp311-cp311-manylinux_2_28_x86_64.whl (38.0 MB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 38.0/38.0 MB 7.0 MB/s eta 0:00:000:00:0100:01
# Downloading pydata_sphinx_theme-0.15.4-py3-none-any.whl (4.6 MB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 4.6/4.6 MB 15.5 MB/s eta 0:00:00:00:01
# Downloading rioxarray-0.15.7-py3-none-any.whl (60 kB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 60.6/60.6 kB 13.0 MB/s eta 0:00:00
# Downloading s3fs-2024.9.0-py3-none-any.whl (29 kB)
# Downloading ujson-5.10.0-cp311-cp311-manylinux_2_17_x86_64.manylinux2014_x86_64.whl (53 kB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 53.6/53.6 kB 4.7 MB/s eta 0:00:00
# Downloading uvicorn-0.24.0.post1-py3-none-any.whl (59 kB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 59.7/59.7 kB 12.8 MB/s eta 0:00:00
# Downloading aiobotocore-2.15.1-py3-none-any.whl (77 kB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 77.4/77.4 kB 10.9 MB/s eta 0:00:00
# Downloading aiohttp-3.10.5-cp311-cp311-manylinux_2_17_x86_64.manylinux2014_x86_64.whl (1.3 MB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 1.3/1.3 MB 102.1 MB/s eta 0:00:00
# Downloading anyio-3.7.1-py3-none-any.whl (80 kB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 80.9/80.9 kB 20.3 MB/s eta 0:00:00
# Downloading docutils-0.21.2-py3-none-any.whl (587 kB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 587.4/587.4 kB 2.4 MB/s eta 0:00:00:00:01
# Downloading fiona-1.10.1-cp311-cp311-manylinux_2_17_x86_64.manylinux2014_x86_64.whl (17.3 MB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 17.3/17.3 MB 21.2 MB/s eta 0:00:00:00:0100:01
# Downloading google_auth-2.35.0-py2.py3-none-any.whl (208 kB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 209.0/209.0 kB 34.6 MB/s eta 0:00:00
# Downloading httptools-0.6.1-cp311-cp311-manylinux_2_5_x86_64.manylinux1_x86_64.manylinux_2_17_x86_64.manylinux2014_x86_64.whl (318 kB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 318.5/318.5 kB 55.9 MB/s eta 0:00:00
# Downloading hydrotools_restclient-3.1.0-py3-none-any.whl (19 kB)
# Downloading sphinx-8.0.2-py3-none-any.whl (3.5 MB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 3.5/3.5 MB 28.2 MB/s eta 0:00:00:00:01
# Downloading pygments-2.18.0-py3-none-any.whl (1.2 MB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 1.2/1.2 MB 56.0 MB/s eta 0:00:00
# Downloading starlette-0.27.0-py3-none-any.whl (66 kB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 67.0/67.0 kB 11.4 MB/s eta 0:00:00
# Downloading uvloop-0.20.0-cp311-cp311-manylinux_2_17_x86_64.manylinux2014_x86_64.whl (3.5 MB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 3.5/3.5 MB 23.5 MB/s eta 0:00:00:00:01
# Downloading watchfiles-0.24.0-cp311-cp311-manylinux_2_17_x86_64.manylinux2014_x86_64.whl (425 kB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 425.5/425.5 kB 57.3 MB/s eta 0:00:00
# Downloading websockets-13.0.1-cp311-cp311-manylinux_2_5_x86_64.manylinux1_x86_64.manylinux_2_17_x86_64.manylinux2014_x86_64.whl (157 kB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 157.9/157.9 kB 24.5 MB/s eta 0:00:00
# Downloading accessible_pygments-0.0.5-py3-none-any.whl (1.4 MB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 1.4/1.4 MB 51.0 MB/s eta 0:00:00
# Downloading google_auth_oauthlib-1.2.1-py2.py3-none-any.whl (24 kB)
# Downloading google_cloud_storage-2.18.2-py2.py3-none-any.whl (130 kB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 130.5/130.5 kB 16.5 MB/s eta 0:00:00
# Downloading aiohappyeyeballs-2.4.0-py3-none-any.whl (12 kB)
# Downloading aiohttp_client_cache-0.11.1-py3-none-any.whl (32 kB)
# Downloading aioitertools-0.12.0-py3-none-any.whl (24 kB)
# Downloading aiosignal-1.3.1-py3-none-any.whl (7.6 kB)
# Downloading aiosqlite-0.20.0-py3-none-any.whl (15 kB)
# Downloading alabaster-1.0.0-py3-none-any.whl (13 kB)
# Downloading botocore-1.35.23-py3-none-any.whl (12.6 MB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 12.6/12.6 MB 21.9 MB/s eta 0:00:00:00:010:01
# Downloading cachetools-5.5.0-py3-none-any.whl (9.5 kB)
# Downloading frozenlist-1.4.1-cp311-cp311-manylinux_2_5_x86_64.manylinux1_x86_64.manylinux_2_17_x86_64.manylinux2014_x86_64.whl (272 kB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 272.3/272.3 kB 42.4 MB/s eta 0:00:00
# Downloading google_api_core-2.20.0-py3-none-any.whl (142 kB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 142.2/142.2 kB 25.8 MB/s eta 0:00:00
# Downloading google_cloud_core-2.4.1-py2.py3-none-any.whl (29 kB)
# Downloading google_crc32c-1.6.0-cp311-cp311-manylinux_2_17_x86_64.manylinux2014_x86_64.whl (32 kB)
# Downloading google_resumable_media-2.7.2-py2.py3-none-any.whl (81 kB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 81.3/81.3 kB 15.6 MB/s eta 0:00:00
# Downloading imagesize-1.4.1-py2.py3-none-any.whl (8.8 kB)
# Downloading pyasn1_modules-0.4.1-py3-none-any.whl (181 kB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 181.5/181.5 kB 32.0 MB/s eta 0:00:00
# Downloading requests_oauthlib-2.0.0-py2.py3-none-any.whl (24 kB)
# Downloading rsa-4.9-py3-none-any.whl (34 kB)
# Downloading snowballstemmer-2.2.0-py2.py3-none-any.whl (93 kB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 93.0/93.0 kB 19.4 MB/s eta 0:00:00
# Downloading sphinxcontrib_htmlhelp-2.1.0-py3-none-any.whl (98 kB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 98.7/98.7 kB 23.6 MB/s eta 0:00:00
# Downloading sphinxcontrib_serializinghtml-2.0.0-py3-none-any.whl (92 kB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 92.1/92.1 kB 20.8 MB/s eta 0:00:00
# Downloading wrapt-1.16.0-cp311-cp311-manylinux_2_5_x86_64.manylinux1_x86_64.manylinux_2_17_x86_64.manylinux2014_x86_64.whl (80 kB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 80.7/80.7 kB 15.7 MB/s eta 0:00:00
# Downloading python_forge-18.6.0-py35-none-any.whl (31 kB)
# Downloading sphinxcontrib_applehelp-2.0.0-py3-none-any.whl (119 kB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 119.3/119.3 kB 21.0 MB/s eta 0:00:00
# Downloading sphinxcontrib_devhelp-2.0.0-py3-none-any.whl (82 kB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 82.5/82.5 kB 17.7 MB/s eta 0:00:00
# Downloading sphinxcontrib_jsmath-1.0.1-py2.py3-none-any.whl (5.1 kB)
# Downloading sphinxcontrib_qthelp-2.0.0-py3-none-any.whl (88 kB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 88.7/88.7 kB 16.3 MB/s eta 0:00:00
# Downloading googleapis_common_protos-1.65.0-py2.py3-none-any.whl (220 kB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 220.9/220.9 kB 44.6 MB/s eta 0:00:00
# Downloading itsdangerous-2.2.0-py3-none-any.whl (16 kB)
# Downloading jmespath-1.0.1-py3-none-any.whl (20 kB)
# Downloading proto_plus-1.24.0-py3-none-any.whl (50 kB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 50.1/50.1 kB 11.1 MB/s eta 0:00:00
# Downloading protobuf-5.28.2-cp38-abi3-manylinux2014_x86_64.whl (316 kB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 316.6/316.6 kB 53.4 MB/s eta 0:00:00
# Downloading pyasn1-0.6.1-py3-none-any.whl (83 kB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 83.1/83.1 kB 15.3 MB/s eta 0:00:00
# Downloading url_normalize-1.4.3-py2.py3-none-any.whl (6.8 kB)
# Building wheels for collected packages: teehr
#   Building wheel for teehr (pyproject.toml) ... done
#   Created wheel for teehr: filename=teehr-0.3.28-py3-none-any.whl size=84263 sha256=13c4ab815b8ab65a80f7cd0901b5f35ba2157a7df4b92d645145cffab917cf2f
#   Stored in directory: /tmp/pip-ephem-wheel-cache-mxjarl1q/wheels/bd/ba/de/fbdfcaf709be29665cd83680691593a3ebe22a2f41760e34fe
# Successfully built teehr
# Installing collected packages: snowballstemmer, python-forge, wrapt, websockets, uvloop, uvicorn, url-normalize, ujson, sphinxcontrib-serializinghtml, sphinxcontrib-qthelp, sphinxcontrib-jsmath, sphinxcontrib-htmlhelp, sphinxcontrib-devhelp, sphinxcontrib-applehelp, pygments, pyasn1, pyarrow, protobuf, jmespath, itsdangerous, imagesize, httptools, h5py, google-crc32c, frozenlist, duckdb, docutils, cachetools, anyio, alabaster, aiosqlite, aioitertools, aiohappyeyeballs, watchfiles, starlette, sphinx, rsa, requests-oauthlib, pyasn1-modules, proto-plus, httpx, googleapis-common-protos, google-resumable-media, fiona, botocore, aiosignal, accessible-pygments, pydata-sphinx-theme, kerchunk, hydrotools-metrics, google-auth, geopandas, fastapi, aiohttp, rioxarray, google-auth-oauthlib, google-api-core, aiohttp-client-cache, aiobotocore, s3fs, google-cloud-core, hydrotools.-restclient, google-cloud-storage, hydrotools-nwis-client, gcsfs, teehr
#   Attempting uninstall: uvicorn
#     Found existing installation: uvicorn 0.30.1
#     Uninstalling uvicorn-0.30.1:
#       Successfully uninstalled uvicorn-0.30.1
#   Attempting uninstall: pygments
#     Found existing installation: Pygments 2.16.1
#     Uninstalling Pygments-2.16.1:
#       Successfully uninstalled Pygments-2.16.1
#   Attempting uninstall: pyarrow
#     Found existing installation: pyarrow 15.0.0
#     Uninstalling pyarrow-15.0.0:
#       Successfully uninstalled pyarrow-15.0.0
#   Attempting uninstall: anyio
#     Found existing installation: anyio 4.4.0
#     Uninstalling anyio-4.4.0:
#       Successfully uninstalled anyio-4.4.0
#   Attempting uninstall: starlette
#     Found existing installation: starlette 0.37.2
#     Uninstalling starlette-0.37.2:
#       Successfully uninstalled starlette-0.37.2
#   Attempting uninstall: httpx
#     Found existing installation: httpx 0.27.0
#     Uninstalling httpx-0.27.0:
#       Successfully uninstalled httpx-0.27.0
#   Attempting uninstall: geopandas
#     Found existing installation: geopandas 1.0.1
#     Uninstalling geopandas-1.0.1:
#       Successfully uninstalled geopandas-1.0.1
#   Attempting uninstall: fastapi
#     Found existing installation: fastapi 0.110.1
#     Uninstalling fastapi-0.110.1:
#       Successfully uninstalled fastapi-0.110.1
#   Attempting uninstall: rioxarray
#     Found existing installation: rioxarray 0.17.0
#     Uninstalling rioxarray-0.17.0:
#       Successfully uninstalled rioxarray-0.17.0
# ERROR: pip's dependency resolver does not currently take into account all the packages that are installed. This behaviour is the source of the following dependency conflicts.
# hydromt-sfincs 1.1.0 requires geopandas>=1.0, but you have geopandas 0.14.4 which is incompatible.
# Successfully installed accessible-pygments-0.0.5 aiobotocore-2.15.1 aiohappyeyeballs-2.4.0 aiohttp-3.10.5 aiohttp-client-cache-0.11.1 aioitertools-0.12.0 aiosignal-1.3.1 aiosqlite-0.20.0 alabaster-1.0.0 anyio-3.7.1 botocore-1.35.23 cachetools-5.5.0 docutils-0.21.2 duckdb-0.9.2 fastapi-0.103.2 fiona-1.10.1 frozenlist-1.4.1 gcsfs-2024.9.0.post1 geopandas-0.14.4 google-api-core-2.20.0 google-auth-2.35.0 google-auth-oauthlib-1.2.1 google-cloud-core-2.4.1 google-cloud-storage-2.18.2 google-crc32c-1.6.0 google-resumable-media-2.7.2 googleapis-common-protos-1.65.0 h5py-3.11.0 httptools-0.6.1 httpx-0.25.2 hydrotools-metrics-1.3.3 hydrotools-nwis-client-3.3.1 hydrotools.-restclient-3.1.0 imagesize-1.4.1 itsdangerous-2.2.0 jmespath-1.0.1 kerchunk-0.2.6 proto-plus-1.24.0 protobuf-5.28.2 pyarrow-14.0.2 pyasn1-0.6.1 pyasn1-modules-0.4.1 pydata-sphinx-theme-0.15.4 pygments-2.18.0 python-forge-18.6.0 requests-oauthlib-2.0.0 rioxarray-0.15.7 rsa-4.9 s3fs-2024.9.0 snowballstemmer-2.2.0 sphinx-8.0.2 sphinxcontrib-applehelp-2.0.0 sphinxcontrib-devhelp-2.0.0 sphinxcontrib-htmlhelp-2.1.0 sphinxcontrib-jsmath-1.0.1 sphinxcontrib-qthelp-2.0.0 sphinxcontrib-serializinghtml-2.0.0 starlette-0.27.0 teehr-0.3.28 ujson-5.10.0 url-normalize-1.4.3 uvicorn-0.24.0.post1 uvloop-0.20.0 watchfiles-0.24.0 websockets-13.0.1 wrapt-1.16.0

# %%
from teehr.loading.nwm import retrospective_points as nwm_retro
from datetime import datetime
# Define the parameters.
NWM_VERSION = "nwm30"
VARIABLE_NAME = "streamflow"
START_DATE = datetime(2019, 5, 20)
END_DATE = datetime(2019, 5, 28)
LOCATION_IDS = feature_ids

OUTPUT_ROOT = Path("/app/data/NWM/")
OUTPUT_DIR = Path(OUTPUT_ROOT, "nwm30_retrospective")

# %%
# Fetch and load the data.
nwm_retro.nwm_retro_to_parquet(
    nwm_version=NWM_VERSION,
    variable_name=VARIABLE_NAME,
    start_date=START_DATE,
    end_date=END_DATE,
    location_ids=LOCATION_IDS,
    output_parquet_dir=OUTPUT_DIR
)

# %%
flow_data = pd.read_parquet(OUTPUT_DIR / "20190520_20190528.parquet")
flow_data[['nwm_version', 'location_id']] = flow_data['location_id'].str.split('-', expand=True)

# %%
root = zarr.open_group(path="/app/data/NWM/nwm30_retrospective.zarr", mode="w")
flood_root = root.require_group("coffeyville.zarr")
flood_root.array(
    name="value_time",
    data=np.array(flow_data["value_time"].unique()),
    dtype="datetime64[ns]"
)
# Out:
# <zarr.core.Array '/app/data/NWM/nwm30_retrospective.zarr/coffeyville.zarr/value_time' (216,) datetime64[ns]>

# %%
for k, v in mapping.items():
    v = np.array([str(int(_v)) for _v in v])
    flow = flow_data[flow_data["location_id"].isin(v)].groupby("value_time")["value"].mean().reset_index()["value"].values
    flood_root.array(
        name=k,
        data=flow,
    )

# %% [markdown]
# Determine source point catchment ID numbers for properly assigning inflow

# %%
gdf_src = workflows.flwdir.river_source_points(
    gdf_riv=_subset_flowlines,
    gdf_mask=sf.region,
    src_type="inflow",
    buffer=200,
    river_upa=10.0,
    river_len=1e3,
    da_uparea=None,
    reverse_river_geom=False,
    logger=sf.logger,
)

# %%
fig, ax = plt.subplots(figsize=(10,10))
_subset_flowlines.plot(ax=ax, color='blue', linewidth=0.5, alpha=0.5, label='Flowlines')
gdf_src.plot(ax=ax, color='red', markersize=30, label='Source Points')
try:
    cx.add_basemap(ax, crs=gdf_src.crs.to_string(), source=cx.providers.OpenStreetMap.Mapnik)
except Exception as e:
    print(f"Couldn't add basemap: {e}")
ax.legend()
plt.tight_layout()
plt.show()

# %%
buffered_lines = _subset_flowlines.copy()
buffered_lines['geometry'] = _subset_flowlines.geometry.buffer(50)
intersection = gpd.overlay(gdf_src, buffered_lines, how='intersection')

# %%
sf.setup_config(
    **{
        "tref": "20190520 000000",
        "tstart": "20190520 000000",
        "tstop": "20190527 000000",
    }
)

# %%
time = flood_root["value_time"][:]
dis = []
for _id in intersection["id"]:
    dis.append(flood_root[_id][:])
dis = np.array(dis).T

index = sf.forcing["dis"].index
dispd = pd.DataFrame(index=time, columns=index, data=dis)
# # now we call the function setup_discharge_forcing, which adds the discharge forcing to the src points
sf.setup_discharge_forcing(timeseries=dispd)

# # NOTE: the discharge forcing data is now stored in the sf.forcing dictionary
sf.forcing.keys()
# Out:
# dict_keys(['dis'])

# %% [markdown]
# ### Step 10: Add weirfile:
# In SFINCS, a weirfile is often used to explicity account for line-element features such as dikes, dunes or floodwalls. Read more about structures in the [SFINCS manual](https://sfincs.readthedocs.io/en/latest/input_structures.html)

# %%
weir_gdf = gpd.read_file("/app/data/NWM/nld_subset_levees.gpkg")
weir_gdf.to_file("/app/data/NWM/nld_subset_levees.geojson", driver='GeoJSON')
# In this example specify a 'line' style shapefile for the location of the weir to be added
# NOTE: optional: dz argument - If provided, for weir structures the z value is calculated from the model elevation (dep) plus dz.
sf.setup_structures(
    structures="/app/data/NWM/nld_subset_levees.geojson",
    stype="weir",
    dz=None,
)

# NOTE: the observation points are now stored in the sf.geoms dictionary
sf.geoms.keys()
# Out:
# dict_keys(['region', 'rivers_inflow', 'weir'])

# %% [markdown]
# ### Step 11: Show and write model settings to disk

# %%
# Use predefined plotting function 'plot_basemap' to show your full SFINCS model setup
_ = sf.plot_basemap(fn_out="basemap.png", bmap="sat", zoomlevel=12)

# %%
sf.write()  # write all
dir_list = os.listdir(sf.root)
print(dir_list)
# Out:
# ['hydromt_data.yml', 'sfincs_subgrid.nc', 'sfincs.dis', 'sfincs.src', '.ipynb_checkpoints', '10m_huc6_lidar.yml', 'figs', 'gis', 'sfincs.inp', 'HUC6_110701_dem.tiff', 'sfincs.weir', 'hydromt.log', '.gitkeep', 'sfincs.ind', 'sfincs.msk']

# %% [markdown]
# Now, we can proceed to the `run_sfincs_from_nwm.ipynb` to run and visualize this flood model!
